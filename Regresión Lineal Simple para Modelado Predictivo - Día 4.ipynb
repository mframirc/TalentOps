# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, r2_score
import scipy.stats as stats

# Generar dataset de clientes para modelado CLV
np.random.seed(42)
n_clientes = 200

df = pd.DataFrame({
    'cliente_id': range(1, n_clientes + 1),
    'edad': np.random.normal(35, 10, n_clientes).clip(18, 70).astype(int),
    'ingresos': np.random.lognormal(10.5, 0.6, n_clientes).round(0),
    'frecuencia_compras': np.random.poisson(4, n_clientes),
    'antiguedad_meses': np.random.exponential(24, n_clientes).astype(int),
    'satisfaccion': np.random.normal(7.5, 1.2, n_clientes).clip(1, 10),
    'canal_adquisicion': np.random.choice(['Online', 'Tienda', 'App'], n_clientes)
})

# Generar CLV basado en características (con ruido)
clv_base = (df['ingresos'] * 0.02 +
            df['frecuencia_compras'] * 50 +
            df['antiguedad_meses'] * 2 +
            df['satisfaccion'] * 30)

df['clv'] = clv_base + np.random.normal(0, clv_base.std() * 0.3, n_clientes)
df['clv'] = df['clv'].clip(0)  # CLV no puede ser negativo

print("DATASET PARA MODELADO CLV")
print("=" * 30)
print(f"Clientes analizados: {len(df)}")
print(f"CLV promedio: ${df['clv'].mean():.0f}")
print(f"Rango CLV: ${df['clv'].min():.0f} - ${df['clv'].max():.0f}")

# Análisis de correlaciones
numeric_cols = ['edad', 'ingresos', 'frecuencia_compras', 'antiguedad_meses', 'satisfaccion', 'clv']
correlaciones = df[numeric_cols].corr()['clv'].sort_values(ascending=False)

print("\nCORRELACIONES CON CLV:")
for var, corr in correlaciones.items():
    if var != 'clv':
        print(f"{var:20} | {corr:+.3f}")

# Modelo de regresión lineal múltiple
modelo = smf.ols('clv ~ edad + ingresos + frecuencia_compras + antiguedad_meses + satisfaccion + C(canal_adquisicion)', data=df).fit()
print("\nRESUMEN DEL MODELO DE REGRESIÓN")
print(modelo.summary())

# Predicciones
df['clv_pred'] = modelo.predict(df)

# Métricas de desempeño
rmse = np.sqrt(mean_squared_error(df['clv'], df['clv_pred']))
r2 = r2_score(df['clv'], df['clv_pred'])
print(f"\nRMSE: {rmse:.2f}")
print(f"R²: {r2:.3f}")

# Visualización: CLV real vs predicho
plt.figure(figsize=(8,6))
plt.scatter(df['clv'], df['clv_pred'], alpha=0.6)
plt.plot([df['clv'].min(), df['clv'].max()],
         [df['clv'].min(), df['clv'].max()],
         color='red', linestyle='--')
plt.xlabel("CLV Real")
plt.ylabel("CLV Predicho")
plt.title("Comparación CLV Real vs Predicho")
plt.show()
# Out:
# DATASET PARA MODELADO CLV
# ==============================
# Clientes analizados: 200
# CLV promedio: $1384
# Rango CLV: $317 - $8112
#
# CORRELACIONES CON CLV:
# ingresos             | +0.940
# frecuencia_compras   | +0.252
# edad                 | +0.064
# antiguedad_meses     | +0.063
# satisfaccion         | -0.061
#
# RESUMEN DEL MODELO DE REGRESIÓN
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    clv   R-squared:                       0.916
# Model:                            OLS   Adj. R-squared:                  0.913
# Method:                 Least Squares   F-statistic:                     300.6
# Date:                Mon, 15 Dec 2025   Prob (F-statistic):          8.00e-100
# Time:                        18:55:57   Log-Likelihood:                -1361.6
# No. Observations:                 200   AIC:                             2739.
# Df Residuals:                     192   BIC:                             2766.
# Df Model:                           7
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                        -63.0116    125.564     -0.502      0.616    -310.674     184.651
# C(canal_adquisicion)[T.Online]   -24.9749     39.550     -0.631      0.528    -102.983      53.033
# C(canal_adquisicion)[T.Tienda]   -18.2217     39.565     -0.461      0.646     -96.261      59.817
# edad                              -0.0597      1.760     -0.034      0.973      -3.531       3.412
# ingresos                           0.0202      0.000     43.797      0.000       0.019       0.021
# frecuencia_compras                55.6073      8.125      6.844      0.000      39.581      71.633
# antiguedad_meses                   2.6759      0.677      3.950      0.000       1.340       4.012
# satisfaccion                      34.7308     13.467      2.579      0.011       8.168      61.293
# ==============================================================================
# Omnibus:                        0.659   Durbin-Watson:                   1.948
# Prob(Omnibus):                  0.719   Jarque-Bera (JB):                0.669
# Skew:                           0.136   Prob(JB):                        0.716
# Kurtosis:                       2.924   Cond. No.                     4.63e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.63e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# RMSE: 218.99
# R²: 0.916

# %%
#2. **Construcción del modelo de regresión lineal**:
import statsmodels.formula.api as smf
from sklearn.metrics import r2_score, mean_squared_error
import numpy as np

# Modelo 1: Usando ingresos como predictor principal
modelo1 = smf.ols('clv ~ ingresos', data=df).fit()

print("\nMODELO 1: CLV ~ INGRESOS")
print("=" * 25)
print(modelo1.summary().tables[1])  # Tabla de coeficientes

# Métricas de evaluación
y_pred1 = modelo1.predict(df['ingresos'])
r2_1 = r2_score(df['clv'], y_pred1)
rmse_1 = np.sqrt(mean_squared_error(df['clv'], y_pred1))

print(f"R²: {r2_1:.4f}")
print(f"RMSE: {rmse_1:.0f}")

# Modelo 2: Múltiples predictores
modelo2 = smf.ols('clv ~ ingresos + frecuencia_compras + antiguedad_meses + satisfaccion',
                  data=df).fit()

print("\nMODELO 2: CLV ~ MÚLTIPLES PREDICTORES")
print("=" * 40)
print(modelo2.summary().tables[1])

# Métricas del modelo múltiple
y_pred2 = modelo2.predict(df[['ingresos', 'frecuencia_compras', 'antiguedad_meses', 'satisfaccion']])
r2_2 = r2_score(df['clv'], y_pred2)
rmse_2 = np.sqrt(mean_squared_error(df['clv'], y_pred2))

print(f"R²: {r2_2:.4f}")
print(f"RMSE: {rmse_2:.0f}")

# Comparación de modelos
mejora_r2 = ((r2_2 - r2_1) / r2_1) * 100
mejora_rmse = ((rmse_1 - rmse_2) / rmse_1) * 100

print("\nCOMPARACIÓN DE MODELOS:")
print(f"Mejora R²: {mejora_r2:.1f}%")
print(f"Mejora RMSE: {mejora_rmse:.1f}%")
# Out:
# MODELO 1: CLV ~ INGRESOS
# =========================
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    448.1782     30.283     14.800      0.000     388.459     507.897
# ingresos       0.0204      0.001     38.841      0.000       0.019       0.021
# ==============================================================================
# R²: 0.8840
# RMSE: 258
#
# MODELO 2: CLV ~ MÚLTIPLES PREDICTORES
# ========================================
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept            -83.0423    110.407     -0.752      0.453    -300.788     134.704
# ingresos               0.0202      0.000     44.420      0.000       0.019       0.021
# frecuencia_compras    55.6135      8.058      6.901      0.000      39.721      71.506
# antiguedad_meses       2.6863      0.670      4.010      0.000       1.365       4.008
# satisfaccion          35.1456     13.308      2.641      0.009       8.900      61.391
# ======================================================================================
# R²: 0.9162
# RMSE: 219
#
# COMPARACIÓN DE MODELOS:
# Mejora R²: 3.6%
# Mejora RMSE: 15.0%

# %%
#Interpretación de coeficientes:
# Extraer coeficientes del modelo múltiple
coeficientes = modelo2.params
p_values = modelo2.pvalues
conf_int = modelo2.conf_int()

print("\nINTERPRETACIÓN DE COEFICIENTES")
print("=" * 35)

for var in ['ingresos', 'frecuencia_compras', 'antiguedad_meses', 'satisfaccion']:
    coef = coeficientes[var]
    p_val = p_values[var]
    ci_lower, ci_upper = conf_int.loc[var]

    print(f"{var.upper()}:")
    print(f"   Coeficiente: {coef:.2f}")
    print(f"   IC 95%: ({ci_lower:.2f}, {ci_upper:.2f})")
    print(f"   Significativo: {'Sí' if p_val < 0.05 else 'No'} (p={p_val:.4f})")

    # Interpretación específica
    if var == 'ingresos':
        print(f"   Por cada aumento de 1 unidad en ingresos, el CLV cambia en {coef:.0f} unidades.")
    elif var == 'frecuencia_compras':
        print(f"   Cada compra adicional se asocia con un cambio de {coef:.0f} en el CLV.")
    elif var == 'antiguedad_meses':
        print(f"   Cada mes adicional de antigüedad incrementa el CLV en {coef:.0f} unidades.")
    elif var == 'satisfaccion':
        print(f"   Un punto extra en satisfacción se relaciona con un cambio de {coef:.2f} en el CLV.")
    print()
# Out:
# INTERPRETACIÓN DE COEFICIENTES
# ===================================
# INGRESOS:
#    Coeficiente: 0.02
#    IC 95%: (0.02, 0.02)
#    Significativo: Sí (p=0.0000)
#    Por cada aumento de 1 unidad en ingresos, el CLV cambia en 0 unidades.
#
# FRECUENCIA_COMPRAS:
#    Coeficiente: 55.61
#    IC 95%: (39.72, 71.51)
#    Significativo: Sí (p=0.0000)
#    Cada compra adicional se asocia con un cambio de 56 en el CLV.
#
# ANTIGUEDAD_MESES:
#    Coeficiente: 2.69
#    IC 95%: (1.37, 4.01)
#    Significativo: Sí (p=0.0001)
#    Cada mes adicional de antigüedad incrementa el CLV en 3 unidades.
#
# SATISFACCION:
#    Coeficiente: 35.15
#    IC 95%: (8.90, 61.39)
#    Significativo: Sí (p=0.0089)
#    Un punto extra en satisfacción se relaciona con un cambio de 35.15 en el CLV.

# %%
# 4. **Validación de supuestos y diagnóstico**
# Análisis de residuos
residuos = modelo2.resid
valores_ajustados = modelo2.fittedvalues

print("VALIDACIÓN DE SUPUESTOS")
print("=" * 25)

# Prueba de normalidad de residuos
stat, p_normalidad = stats.shapiro(residuos)
print(f"Normalidad residuos: {'Sí' if p_normalidad > 0.05 else 'No'} (p={p_normalidad:.4f})")

# Prueba de homocedasticidad (Breusch-Pagan)
from statsmodels.stats.api import het_breuschpagan
bp_test = het_breuschpagan(residuos, modelo2.model.exog)
print(f"Homocedasticidad: {'Sí' if bp_test[1] > 0.05 else 'No'} (p={bp_test[1]:.4f})")

# Correlación de residuos (Durbin-Watson)
from statsmodels.stats.stattools import durbin_watson
dw_stat = durbin_watson(residuos)
print(f"Independencia residuos (DW): {dw_stat:.3f} (ideal: 2.0)")

# Multicolinealidad (VIF)
from statsmodels.stats.outliers_influence import variance_inflation_factor
X = df[['ingresos', 'frecuencia_compras', 'antiguedad_meses', 'satisfaccion']]
vif_data = pd.DataFrame()
vif_data["Variable"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

print("MULTICOLINEALIDAD (VIF):")
for _, row in vif_data.iterrows():
    problema = "PROBLEMA" if row['VIF'] > 5 else "OK"
    print(f"{row['Variable']:20} | VIF={row['VIF']:.2f} | {problema}")
# Out:
# VALIDACIÓN DE SUPUESTOS
# =========================
# Normalidad residuos: Sí (p=0.2083)
# Homocedasticidad: Sí (p=0.4250)
# Independencia residuos (DW): 1.952 (ideal: 2.0)
# MULTICOLINEALIDAD (VIF):
# ingresos             | VIF=2.60 | OK
# frecuencia_compras   | VIF=4.53 | OK
# antiguedad_meses     | VIF=1.97 | OK
# satisfaccion         | VIF=5.64 | PROBLEMA

# %%
# Visualización completa del modelo
import matplotlib.pyplot as plt
import scipy.stats as stats
from statsmodels.stats.diagnostic import het_breuschpagan
from statsmodels.stats.stattools import durbin_watson

# Residuos y valores ajustados
residuos = modelo2.resid
valores_ajustados = modelo2.fittedvalues

# Crear visualización comprehensiva del modelo
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(16, 12))

# 1. Valores observados vs predichos
ax1.scatter(df['clv'], y_pred2, alpha=0.6, color='#1f77b4')
ax1.plot([df['clv'].min(), df['clv'].max()],
         [df['clv'].min(), df['clv'].max()],
         'r--', linewidth=2, label='Línea perfecta')
ax1.set_xlabel('CLV Observado ($)')
ax1.set_ylabel('CLV Predicho ($)')
ax1.set_title('Valores Observados vs Predichos', fontweight='bold')
ax1.legend()
ax1.grid(True, alpha=0.3)

# 2. Residuos vs valores ajustados
ax2.scatter(valores_ajustados, residuos, alpha=0.6, color='#ff7f0e')
ax2.axhline(y=0, color='red', linestyle='--', linewidth=2)
ax2.set_xlabel('Valores Ajustados')
ax2.set_ylabel('Residuos')
ax2.set_title('Diagnóstico: Residuos vs Valores Ajustados', fontweight='bold')
ax2.grid(True, alpha=0.3)

# 3. Q-Q plot de residuos
stats.probplot(residuos, dist="norm", plot=ax3)
ax3.set_title('Q-Q Plot: Normalidad de Residuos', fontweight='bold')

# 4. Importancia de variables (coeficientes estandarizados)
coef_std = modelo2.params[1:] / df[['ingresos', 'frecuencia_compras', 'antiguedad_meses', 'satisfaccion']].std()
coef_std = coef_std.abs().sort_values(ascending=True)

bars = ax4.barh(range(len(coef_std)), coef_std.values, color='#2ca02c', alpha=0.7)
ax4.set_yticks(range(len(coef_std)))
ax4.set_yticklabels(coef_std.index)
ax4.set_xlabel('Importancia (Coeficiente Estandarizado)')
ax4.set_title('Importancia Relativa de Variables', fontweight='bold')

# Añadir valores en las barras
for i, (var, val) in enumerate(zip(coef_std.index, coef_std.values)):
    ax4.text(val + 0.01, i, f"{val:.2f}", va='center', fontweight='bold')

plt.tight_layout()
plt.savefig('modelo_regresion_clv_completo.png', dpi=300, bbox_inches='tight')
print("\nAnálisis de modelo guardado como 'modelo_regresion_clv_completo.png'")

# --- Resumen ejecutivo ---
# Test de normalidad (Shapiro-Wilk)
p_normalidad = stats.shapiro(residuos)[1]

# Test de heterocedasticidad (Breusch-Pagan)
bp_test = het_breuschpagan(residuos, modelo2.model.exog)

# Test de autocorrelación (Durbin-Watson)
dw_stat = durbin_watson(residuos)

print("\nRESUMEN EJECUTIVO - MODELO CLV")
print("=" * 35)
print(f"R² del modelo: {r2_2:.1f} ({r2_2*100:.1f}% de variabilidad explicada)")
print(f"RMSE: ${rmse_2:.0f} (error típico de predicción)")
print(f"Variables significativas: {sum(p_values[1:] < 0.05)} de {len(p_values)-1}")
print(f"Supuestos cumplidos: {sum([p_normalidad > 0.05, bp_test[1] > 0.05, abs(dw_stat - 2) < 0.5])} de 3")
# Out:
# Análisis de modelo guardado como 'modelo_regresion_clv_completo.png'
#
# RESUMEN EJECUTIVO - MODELO CLV
# ===================================
# R² del modelo: 0.9 (91.6% de variabilidad explicada)
# RMSE: $219 (error típico de predicción)
# Variables significativas: 4 de 4
# Supuestos cumplidos: 3 de 3

# %%
# Crear DataFrame con datos del nuevo cliente
cliente_nuevo = pd.DataFrame({
    'ingresos': [80000],
    'frecuencia_compras': [8],
    'antiguedad_meses': [36],
    'satisfaccion': [8.5]   # ojo: sin tilde para evitar errores en Python
})

# Predicción usando el modelo múltiple
clv_predicho = modelo2.predict(cliente_nuevo)[0]

print("\nPREDICCIÓN PARA NUEVO CLIENTE")
print("=" * 35)
print(f"Ingresos: ${cliente_nuevo['ingresos'][0]:,.0f}")
print(f"Frecuencia de compras: {cliente_nuevo['frecuencia_compras'][0]}")
print(f"Antigüedad (meses): {cliente_nuevo['antiguedad_meses'][0]}")
print(f"Satisfacción: {cliente_nuevo['satisfaccion'][0]:.1f}")
print(f"\nCLV Predicho: ${clv_predicho:,.0f}")
# Out:
# PREDICCIÓN PARA NUEVO CLIENTE
# ===================================
# Ingresos: $80,000
# Frecuencia de compras: 8
# Antigüedad (meses): 36
# Satisfacción: 8.5
#
# CLV Predicho: $2,374

# %%
"""
Interpretación del coeficiente de ingresos
• El coeficiente de ingresos del modelo múltiple indica el cambio esperado en el CLV por cada unidad adicional de ingresos,
manteniendo constantes las demás variables.
• Ejemplo: si el coeficiente estimado es 0.45, significa que por cada peso adicional en ingresos, 
el CLV aumenta en promedio 0.45 unidades.
• En términos ejecutivos: clientes con mayores ingresos tienden a generar un valor de vida más alto,
lo que refleja que su capacidad de gasto se traduce en relaciones más rentables.

Supuestos del modelo lineal y posibles violaciones
Los principales supuestos son:

1. Linealidad
• Se asume que la relación entre ingresos y CLV es lineal.
• Si en realidad la relación es curvilínea (ej. rendimientos decrecientes en clientes con ingresos muy altos), 
el modelo puede sesgar las predicciones.

2. Independencia de errores
• Los residuos no deberían estar correlacionados.
• Si hay dependencia temporal (ej. clientes con historial de compras correlacionadas), las predicciones pierden precisión.

3.Normalidad de residuos
• Los residuos deberían seguir una distribución normal.
• Si hay colas pesadas o asimetría, los intervalos de confianza y los p-values pierden validez.

4.Homoscedasticidad (varianza constante de los errores)
• Se espera que la dispersión de los residuos sea similar en todos los niveles de ingresos.
• Si clientes con ingresos altos muestran mayor variabilidad en CLV, el modelo subestima la incertidumbre en ese segmento.

5.Ausencia de multicolinealidad
• Los predictores no deben estar fuertemente correlacionados entre sí.
• Si ingresos y frecuencia_compras están muy correlacionados, los coeficientes se vuelven inestables y difíciles de interpretar.

Impacto en la confiabilidad de las predicciones
• Violación de linealidad:Predicciones sesgadas en extremos (clientes muy ricos o muy pobres).
• Heterocedasticidad: Intervalos de confianza poco confiables; el modelo puede parecer más preciso de lo que realmente es.
• No normalidad de residuos: Tests de significancia y p-values menos confiables.
• Multicolinealidad: Dificultad para interpretar qué variable realmente explica el CLV;coeficientes pueden cambiar drásticamente si se modifica el dataset.
• Autocorrelación: Predicciones secuenciales menos confiables, especialmente en datos con historial temporal.

En resumen: el coeficiente de ingresos refleja el impacto marginal de los ingresos sobre el CLV, 
pero si los supuestos están violados, las predicciones para nuevos clientes pueden ser menos confiables en términos 
de precisión y significancia estadística.
"""
